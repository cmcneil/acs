# %%
from typing import List, Dict
import requests
import pandas as pd

# %%
state_fips = {
            'ALABAMA': '01',
            'ALASKA': '02',
            'ARIZONA': '04',
            'ARKANSAS': '05',
            'CALIFORNIA': '06',
            'COLORADO': '08',
            'CONNECTICUT': '09',
            'DELAWARE': '10',
            'DISTRICT OF COLUMBIA': '11',
            'FLORIDA': '12',
            'GEORGIA': '13',
            'HAWAII': '15',
            'IDAHO': '16',
            'ILLINOIS': '17',
            'INDIANA': '18',
            'IOWA': '19',
            'KANSAS': '20',
            'KENTUCKY': '21',
            'LOUISIANA': '22',
            'MAINE': '23',
            'MARYLAND': '24',
            'MASSACHUSETTS': '25',
            'MICHIGAN': '26',
            'MINNESOTA': '27',
            'MISSISSIPPI': '28',
            'MISSOURI': '29',
            'MONTANA': '30',
            'NEBRASKA': '31',
            'NEVADA': '32',
            'NEW HAMPSHIRE': '33',
            'NEW JERSEY': '34',
            'NEW MEXICO': '35',
            'NEW YORK': '36',
            'NORTH CAROLINA': '37',
            'NORTH DAKOTA': '38',
            'OHIO': '39',
            'OKLAHOMA': '40',
            'OREGON': '41',
            'PENNSYLVANIA': '42',
            'RHODE ISLAND': '44',
            'SOUTH CAROLINA': '45',
            'SOUTH DAKOTA': '46',
            'TENNESSEE': '47',
            'TEXAS': '48',
            'UTAH': '49',
            'VERMONT': '50',
            'VIRGINIA': '51',
            'WASHINGTON': '53',
            'WEST VIRGINIA': '54',
            'WISCONSIN': '55',
            'WYOMING': '56',
            'PUERTO RICO': '72'
        }

# %%
class CensusDataRetriever:
    def __init__(self, api_key: str):
        self.api_key = api_key
        self.base_url = "https://api.census.gov/data"
        self.year = "2022"  # Most recent ACS 5-year estimates
        self.dataset = "acs/acs5"
        
    def get_variable_groups(self) -> Dict:
        """Retrieve available variable groups for reference"""
        url = f"{self.base_url}/{self.year}/{self.dataset}/groups.json"
        response = requests.get(url)
        return response.json()
    
    def get_place_data(self, state_fips: str, variables: List[str]) -> pd.DataFrame:
        """
        Retrieve data for all places (cities) in a state
        
        Parameters:
        state_fips: Two-digit state FIPS code
        variables: List of Census variable codes
        """
        # Construct variable string
        var_str = ",".join(variables)
        
        # Build API URL
        url = f"{self.base_url}/{self.year}/{self.dataset}"
        
        # Parameters for the request
        params = {
            "get": f"NAME,{var_str}",
            "for": "place:*",
            "in": f"state:{state_fips}",
            "key": self.api_key
        }
        
        response = requests.get(url, params=params)
        if response.status_code != 200:
            raise Exception(f"API request failed: {response.text}")
            
        # Convert response to DataFrame
        data = response.json()
        df = pd.DataFrame(data[1:], columns=data[0])
        return df

# %%
class CensusDataRetriever:
    def __init__(self, api_key: str):
        self.api_key = api_key
        self.base_url = "https://api.census.gov/data"
        self.year = "2022"  # Most recent ACS 5-year estimates
        self.dataset = "acs/acs5"
        
    def get_variable_groups(self) -> Dict:
        """Retrieve available variable groups for reference"""
        url = f"{self.base_url}/{self.year}/{self.dataset}/groups.json"
        response = requests.get(url)
        return response.json()
    
    def get_metro_data(self, variables: List[str]) -> pd.DataFrame:
        """
        Retrieve data for all Metropolitan Statistical Areas (CBSAs)
        
        Parameters:
        variables: List of Census variable codes
        """
        # Construct variable string
        var_str = ",".join(variables)
        
        # Build API URL
        url = f"{self.base_url}/{self.year}/{self.dataset}"
        
        # Parameters for the request - using CBSA (Core Based Statistical Area) geography
        params = {
            "get": f"NAME,{var_str}",
            "for": "metropolitan statistical area/micropolitan statistical area:*",
            "key": self.api_key
        }
        
        response = requests.get(url, params=params)
        if response.status_code != 200:
            raise Exception(f"API request failed: {response.text}")
            
        # Convert response to DataFrame
        data = response.json()
        df = pd.DataFrame(data[1:], columns=data[0])
        
        # Filter to only metropolitan areas (population >= 50,000)
        # Convert population to numeric for filtering
        df['B01001_001E'] = pd.to_numeric(df['B01001_001E'])
        metro_areas = df[df['B01001_001E'] >= 50000].copy()
        
        return metro_areas
    
    def get_component_places(self, cbsa_code: str, variables: List[str]) -> pd.DataFrame:
        """
        Get all places (cities) within a specific CBSA
        
        Parameters:
        cbsa_code: The CBSA code for the metropolitan area
        variables: List of Census variable codes
        """
        var_str = ",".join(variables)
        url = f"{self.base_url}/{self.year}/{self.dataset}"
        
        params = {
            "get": f"NAME,{var_str}",
            "for": "place:*",
            "in": f"metropolitan statistical area/micropolitan statistical area:{cbsa_code}",
            "key": self.api_key
        }
        
        response = requests.get(url, params=params)
        if response.status_code != 200:
            raise Exception(f"API request failed: {response.text}")
            
        data = response.json()
        return pd.DataFrame(data[1:], columns=data[0])

# %%
API_KEY = "185f22854b5fff8e12d4d135d81adabd7ede4310"
    
  # Initialize retriever
retriever = CensusDataRetriever(API_KEY)

# Example variables for different demographics
# You can find more variables at: https://api.census.gov/data/2022/acs/acs5/variables.html


column_map = {
        'B01001_001E': 'total_population',
        'B01001H_025E': 'female_white_30_34',
        'B01001D_025E': 'female_asian_30_34',
        'B01001D_010E': 'male_asian_30_34',
        'B01001H_010E': 'male_white_30_34',
        'B01001H_011E': 'male_white_35_39',
        'B01001D_011E': 'male_asian_35_39',
        'B01001_036E': 'female_total_30_34',
        'B01001_012E': 'male_total_30_34',
        'B01001_013E': 'male_total_35_39',
        

        'B12002_101E': 'female_never_married_30_34',
        'B12002_102E': 'female_never_married_35_39',
        'B12002_008E': 'male_never_married_30_34',
        'B12002_009E': 'male_never_married_35_39',
}

variables = [k for k, v in column_map.items()]

# %%
ca_data = retriever.get_place_data("06", variables)
ca_data = ca_data.rename(columns=column_map)
num_cols = list(column_map.values())
ca_data[num_cols] = ca_data[num_cols].apply(pd.to_numeric)

# %%
metro_data = retriever.get_metro_data(variables)
metro_data = metro_data.rename(columns=column_map)
num_cols = list(column_map.values())
metro_data[num_cols] = metro_data[num_cols].apply(pd.to_numeric)

# %%
metro_data.head()
# Out:
#                                NAME  total_population  female_white_30_34  \
# 1           Aberdeen, WA Micro Area             75672                1553
# 2            Abilene, TX Metro Area            176656                3395
# 4             Adrian, MI Micro Area             99263                2266
# 5  Aguadilla-Isabela, PR Metro Area            308919                 535
# 6              Akron, OH Metro Area            700578               16223
#
#    female_asian_30_34  male_asian_30_34  male_white_30_34  male_white_35_39  \
# 1                  33                31              1793              3596
# 2                 132               129              3617              6642
# 4                   0                 3              2429              5154
# 5                  16                 0               335               311
# 6                1052              1047             17040             32135
#
#    male_asian_35_39  female_total_30_34  male_total_30_34  male_total_35_39  \
# 1                97                1982              2494              2396
# 2               226                5683              6575              6339
# 4                 7                2666              2932              3401
# 5                20                9099              8927              7757
# 6              1967               21930             22021             20956
#
#    female_never_married_30_34  female_never_married_35_39  \
# 1                         704                         618
# 2                        1406                         935
# 4                         794                         668
# 5                        5504                        3238
# 6                        8727                        4961
#
#    male_never_married_30_34  male_never_married_35_39  \
# 1                      1238                       883
# 2                      2641                      1816
# 4                      1322                      1027
# 5                      6179                      4327
# 6                     10659                      6951
#
#   metropolitan statistical area/micropolitan statistical area
# 1                                              10140
# 2                                              10180
# 4                                              10300
# 5                                              10380
# 6                                              10420

# %%
populous = (metro_data[(metro_data["female_asian_30_34"] > 500) &
            (metro_data["female_never_married_30_34"] > 500)]).copy()

# %%
def favorable_dating_index(df):
    fdi = ((df["female_asian_30_34"] + df["female_white_30_34"])* (df["female_never_married_30_34"] / df["female_total_30_34"])
           / (((df["male_never_married_30_34"] + df["male_never_married_35_39"]) / (df["male_total_30_34"] + df["male_total_35_39"]))
              * (df["male_white_30_34"] + df["male_white_35_39"] + df["male_asian_30_34"] + df["male_asian_35_39"])))
    return fdi

# %%
populous["fdi"] = favorable_dating_index(populous)
populous["f_to_m"] = populous["female_never_married_30_34"] / populous["male_never_married_30_34"]
populous["f_surplus"] = populous["female_never_married_30_34"] - populous["male_never_married_30_34"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 populous["fdi"] = favorable_dating_index(populous)
#       2 populous["f_to_m"] = populous["female_never_married_30_34"] / populous["male_never_married_30_34"]
#       3 populous["f_surplus"] = populous["female_never_married_30_34"] - populous["male_never_married_30_34"]
#
# NameError: name 'populous' is not defined

# %%
len(populous)
# Out:
# 124

# %%
populous.sort_values(by='fdi', ascending=False).head(20)
# Out:
#                                                   NAME  total_population  \
# 434                               Kapaa, HI Micro Area             73511
# 868                      Urban Honolulu, HI Metro Area           1010100
# 759      San Jose-Sunnyvale-Santa Clara, CA Metro Area           1981584
# 757      San Francisco-Oakland-Berkeley, CA Metro Area           4692242
# 377                                Hilo, HI Micro Area            202163
# 825                            Stockton, CA Metro Area            779445
# 429             Kahului-Wailuku-Lahaina, HI Metro Area            164765
# 499      Los Angeles-Long Beach-Anaheim, CA Metro Area          13111917
# 314                              Fresno, CA Metro Area           1008280
# 608   New York-Newark-Jersey City, NY-NJ-PA Metro Area          19908595
# 872                             Vallejo, CA Metro Area            450995
# 736         Sacramento-Roseville-Folsom, CA Metro Area           2394673
# 545                              Merced, CA Metro Area            282290
# 775             Seattle-Tacoma-Bellevue, WA Metro Area           4001701
# 753      San Diego-Chula Vista-Carlsbad, CA Metro Area           3289701
# 896  Washington-Arlington-Alexandria, DC-VA-MD-WV M...           6346083
# 388    Houston-The Woodlands-Sugar Land, TX Metro Area           7142603
# 716    Riverside-San Bernardino-Ontario, CA Metro Area           4610050
# 935                           Yuba City, CA Metro Area            180806
# 854                   Trenton-Princeton, NJ Metro Area            383732
#
#      female_white_30_34  female_asian_30_34  male_asian_30_34  \
# 434                 654                 730               505
# 868                6860               12746             11449
# 759               17584               33853             38438
# 757               62773               59750             56408
# 377                1501                1168              1032
# 825                6675                5114              5065
# 429                1521                1227              1032
# 499              134243               84179             79849
# 314                8996                5204              5260
# 608              284998              103291             95058
# 872                5233                2428              2260
# 736               38034               14844             13336
# 545                2233                 819               992
# 775               91891               33339             33615
# 753               51161               18322             17549
# 896               99832               28141             24944
# 388               81667               24575             21722
# 716               40032               12201             11402
# 935                2920                 958               873
# 854                4696                1486              1370
#
#      male_white_30_34  male_white_35_39  male_asian_35_39  female_total_30_34  \
# 434               578              1419              1166                2225
# 868              8670             14526             24354               34667
# 759             22041             39708             62150               74289
# 757             71307            129367            101334              187300
# 377              1473              3529              2432                6191
# 825              7104             14079              9780               26377
# 429              1420              3439              2836                5241
# 499            147736            258624            145281              493667
# 314              9251             17670              7572               36553
# 608            292612            527611            179360              720294
# 872              5740             10402              4418               15926
# 736             39084             77148             23846               84811
# 545              2345              4314              1341                9472
# 775            100844            181751             51981              166511
# 753             57338            101711             29388              126889
# 896            101277            193679             53617              235299
# 388             84249            166983             44799              262926
# 716             42130             82369             21642              160515
# 935              2974              5297              1475                6512
# 854              4872              9712              4026               11440
#
#      male_total_30_34  male_total_35_39  female_never_married_30_34  \
# 434              2200              2518                        1239
# 868             38550             36251                       13477
# 759             87149             79406                       26066
# 757            198762            190045                       84132
# 377              5974              6551                        3357
# 825             27470             28216                       10700
# 429              5004              6147                        2200
# 499            521972            476114                      245914
# 314             38683             36190                       14813
# 608            728359            681003                      343704
# 872             16942             16085                        6019
# 736             86727             84970                       32539
# 545             10587              9866                        3787
# 775            181272            165845                       60390
# 753            138865            124361                       49213
# 896            233225            239576                       98724
# 388            265333            266336                       91056
# 716            169261            157783                       63187
# 935              6711              6775                        1876
# 854             12007             12524                        5113
#
#      female_never_married_35_39  male_never_married_30_34  \
# 434                         830                      1241
# 868                        9305                     19297
# 759                       14616                     42495
# 757                       51157                    110274
# 377                        2025                      3945
# 825                        7030                     14049
# 429                        1844                      2849
# 499                      149857                    316446
# 314                        9501                     18634
# 608                      208810                    410308
# 872                        3981                      8184
# 736                       19884                     42413
# 545                        2557                      5000
# 775                       34018                     86654
# 753                       27685                     71080
# 896                       65686                    117492
# 388                       60923                    116987
# 716                       36272                     85415
# 935                        1783                      2750
# 854                        3568                      6721
#
#      male_never_married_35_39  \
# 434                      1061
# 868                     12642
# 759                     23836
# 757                     69901
# 377                      2568
# 825                      9424
# 429                      2171
# 499                    196928
# 314                     13349
# 608                    245362
# 872                      5851
# 736                     27494
# 545                      3589
# 775                     50657
# 753                     40917
# 896                     72422
# 388                     74495
# 716                     49154
# 935                      2017
# 854                      4376
#
#     metropolitan statistical area/micropolitan statistical area       fdi  \
# 434                                              28180           0.227137
# 868                                              46520           0.196695
# 759                                              41940           0.183726
# 757                                              41860           0.161590
# 377                                              25900           0.143864
# 825                                              44700           0.136602
# 429                                              27980           0.131099
# 499                                              31080           0.129098
# 314                                              23420           0.124192
# 608                                              35620           0.096784
# 872                                              46700           0.094625
# 736                                              40900           0.091176
# 545                                              32900           0.086715
# 775                                              42660           0.083018
# 753                                              41740           0.081080
# 896                                              47900           0.078696
# 388                                              26420           0.074369
# 716                                              40140           0.074092
# 935                                              49700           0.073526
# 854                                              45940           0.073482
#
#        f_to_m  f_surplus
# 434  0.998388         -2
# 868  0.698399      -5820
# 759  0.613390     -16429
# 757  0.762936     -26142
# 377  0.850951       -588
# 825  0.761620      -3349
# 429  0.772201       -649
# 499  0.777112     -70532
# 314  0.794945      -3821
# 608  0.837673     -66604
# 872  0.735459      -2165
# 736  0.767194      -9874
# 545  0.757400      -1213
# 775  0.696910     -26264
# 753  0.692361     -21867
# 896  0.840261     -18768
# 388  0.778343     -25931
# 716  0.739765     -22228
# 935  0.682182       -874
# 854  0.760750      -1608

# %%
populous.sort_values(by='f_to_m', ascending=False).head(50)
# Out:
#                                                   NAME  total_population  \
# 543                       Memphis, TN-MS-AR Metro Area           1335804
# 603                New Orleans-Metairie, LA Metro Area           1264357
# 434                               Kapaa, HI Micro Area             73511
# 345               Greensboro-High Point, NC Metro Area            775169
# 491  Little Rock-North Little Rock-Conway, AR Metro...            749290
# 90                    Birmingham-Hoover, AL Metro Area           1114368
# 47     Atlanta-Sandy Springs-Alpharetta, GA Metro Area           6094752
# 406                             Jackson, MS Metro Area            591397
# 185                            Columbia, SC Metro Area            831913
# 158         Charleston-North Charleston, SC Metro Area            803398
# 246                  Durham-Chapel Hill, NC Metro Area            648066
# 220                    Dayton-Kettering, OH Metro Area            812506
# 444                      Killeen-Temple, TX Metro Area            477577
# 59            Baltimore-Columbia-Towson, MD Metro Area           2840005
# 68                          Baton Rouge, LA Metro Area            869755
# 665  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD Me...           6232894
# 464                           Lancaster, PA Metro Area            553202
# 400        Indianapolis-Carmel-Anderson, IN Metro Area           2109957
# 173                    Cleveland-Elyria, OH Metro Area           2079759
# 713                            Richmond, VA Metro Area           1316145
# 602                   New Haven-Milford, CT Metro Area            866377
# 595  Nashville-Davidson--Murfreesboro--Franklin, TN...           1990873
# 742                        St. Louis, MO-IL Metro Area           2813523
# 812                         Springfield, MA Metro Area            689486
# 377                                Hilo, HI Micro Area            202163
# 350                 Greenville-Anderson, SC Metro Area            931405
# 883  Virginia Beach-Norfolk-Newport News, VA-NC Met...           1798025
# 722                           Rochester, NY Metro Area           1086859
# 125                 Buffalo-Cheektowaga, NY Metro Area           1163462
# 159       Charlotte-Concord-Gastonia, NC-SC Metro Area           2668688
# 896  Washington-Arlington-Alexandria, DC-VA-MD-WV M...           6346083
# 834                            Syracuse, NY Metro Area            658694
# 105          Boston-Cambridge-Newton, MA-NH Metro Area           4912449
# 608   New York-Newark-Jersey City, NY-NJ-PA Metro Area          19908595
# 555                  Milwaukee-Waukesha, WI Metro Area           1568940
# 564                             Modesto, CA Metro Area            552063
# 500      Louisville/Jefferson County, KY-IN Metro Area           1282588
# 163      Chicago-Naperville-Elgin, IL-IN-WI Metro Area           9566955
# 703                        Raleigh-Cary, NC Metro Area           1420825
# 6                                 Akron, OH Metro Area            700578
# 838     Tampa-St. Petersburg-Clearwater, FL Metro Area           3194310
# 212         Dallas-Fort Worth-Arlington, TX Metro Area           7673379
# 692    Poughkeepsie-Newburgh-Middletown, NY Metro Area            697704
# 768                            Savannah, GA Metro Area            406575
# 629             Omaha-Council Bluffs, NE-IA Metro Area            966688
# 182               College Station-Bryan, TX Metro Area            269418
# 465                Lansing-East Lansing, MI Metro Area            538985
# 166                    Cincinnati, OH-KY-IN Metro Area           2253528
# 696               Providence-Warwick, RI-MA Metro Area           1670949
# 752           San Antonio-New Braunfels, TX Metro Area           2570862
#
#      female_white_30_34  female_asian_30_34  male_asian_30_34  \
# 543               17773                1370              1120
# 603               22271                1657              1242
# 434                 654                 730               505
# 345               12823                1334              1223
# 491               16279                 804               356
# 90                22123                 913               702
# 47                88714               17250             15623
# 406                8283                 524               272
# 185               14469                 846               728
# 158               20195                 614               653
# 246               13052                1502              1589
# 220               19446                 763               832
# 444                8131                 530               539
# 59                53163                7248              6084
# 68                15148                 778               812
# 665              124295               18047             16678
# 464               13863                 617               466
# 400               50859                4082              3358
# 173               42145                2461              2226
# 713               25531                2606              2568
# 602               14285                1650              1485
# 595               53239                3099              2528
# 742               65446                3573              3856
# 812               13282                 636               561
# 377                1501                1168              1032
# 350               20983                 586               761
# 883               33301                3074              2542
# 722               25018                1394              1236
# 125               28695                2083              1629
# 159               52954                5754              5666
# 896               99832               28141             24944
# 834               16023                 852               758
# 105              112387               21392             19937
# 608              284998              103291             95058
# 555               32118                3228              3342
# 564                6880                1466              1411
# 500               31056                1413              1362
# 163              161131               29679             28795
# 703               30123                4317              3592
# 6                 16223                1052              1047
# 838               57425                5100              4591
# 212              114742               26955             24981
# 692               11854                 604               553
# 768                8201                 586               363
# 629               24251                1750              1748
# 182                4199                 548               710
# 465               12582                 875               907
# 166               55756                3150              3118
# 696               38556                2669              2443
# 752               27327                3526              2949
#
#      male_white_30_34  male_white_35_39  male_asian_35_39  female_total_30_34  \
# 543             17612             34597              2682               47873
# 603             21752             42598              2492               47762
# 434               578              1419              1166                2225
# 345             12339             23916              2458               25860
# 491             16126             31463              1147               26729
# 90              21594             42794              1318               38952
# 47              88610            174388             33665              221065
# 406              8000             17152               792               20246
# 185             14295             27463              1385               28529
# 158             19748             36216              1155               31667
# 246             12579             22078              2294               24079
# 220             19841             36595              1504               26563
# 444              8039             14379               707               18510
# 59              53748             97070             13781              105358
# 68              15491             31093              1483               28997
# 665            127442            232252             31434              224640
# 464             13895             24896               897               18066
# 400             50533             97922              7926               76186
# 173             44025             84694              4395               67136
# 713             25381             47633              5175               48272
# 602             14507             28105              2503               28502
# 595             52542             96250              5610               77183
# 742             66358            133209              6799               95853
# 812             13279             25937               929               21143
# 377              1473              3529              2432                6191
# 350             20716             39297              1353               30525
# 883             35848             62972              5032               66396
# 722             25763             47336              2069               35728
# 125             30168             52159              3034               40076
# 159             52748            102145             12025               96560
# 896            101277            193679             53617              235299
# 834             16604             30634              1130               21116
# 105            114371            198043             33785              180852
# 608            292612            527611            179360              720294
# 555             33655             66273              5633               54036
# 564              7089             13297              2367               19372
# 500             31436             61243              2513               43686
# 163            168858            323791             55031              333667
# 703             30233             58960             10271               52391
# 6               17040             32135              1967               21930
# 838             57098            109393              9536              107230
# 212            115403            226244             54319              285000
# 692             12293             24390              1432               19927
# 768              8172             15030               719               15472
# 629             25069             50180              2823               33859
# 182              4419              7640              1241                8785
# 465             12857             24417              1558               16701
# 166             56854            110505              5589               74578
# 696             39289             70852              4360               56385
# 752             29166             54725              5933               93202
#
#      male_total_30_34  male_total_35_39  female_never_married_30_34  \
# 543             44018             40927                       23360
# 603             43663             44721                       25636
# 434              2200              2518                        1239
# 345             23226             22466                       11199
# 491             24751             25412                        9810
# 90              36549             34373                       15058
# 47             208397            209499                       92900
# 406             19390             19257                        8578
# 185             26670             25370                       11915
# 158             30525             29727                       12408
# 246             23663             21267                       10644
# 220             26780             24563                       10885
# 444             18642             17321                        5950
# 59             100417             97405                       47142
# 68              29711             30247                       12689
# 665            221470            204020                      104129
# 464             18011             16317                        5759
# 400             74576             74536                       28074
# 173             66288             62631                       30964
# 713             47295             45919                       21203
# 602             27914             25390                       14028
# 595             74719             71731                       26798
# 742             93443             94282                       36587
# 812             21553             19413                       10210
# 377              5974              6551                        3357
# 350             29870             28426                       10154
# 883             66927             61241                       23957
# 722             36062             32747                       16167
# 125             40576             36686                       18173
# 159             93061             90467                       36718
# 896            233225            239576                       98724
# 834             20876             19721                        9207
# 105            183118            167030                       80782
# 608            728359            681003                      343704
# 555             53494             52113                       23614
# 564             20079             18970                        7775
# 500             44038             42166                       16629
# 163            340086            336316                      145962
# 703             50585             51510                       17434
# 6               22021             20956                        8727
# 838            106346            103814                       43996
# 212            283463            274450                       95882
# 692             21271             20237                        8253
# 768             15235             13601                        5461
# 629             34560             35106                       10902
# 182              9023              8755                        2989
# 465             17182             16540                        6498
# 166             75168             74819                       27136
# 696             57907             54210                       25715
# 752             97897             94643                       34044
#
#      female_never_married_35_39  male_never_married_30_34  \
# 543                       17054                     22486
# 603                       17366                     25559
# 434                         830                      1241
# 345                        6428                     11435
# 491                        6731                     10118
# 90                         9063                     15931
# 47                        62119                     98612
# 406                        6527                      9222
# 185                        7892                     12835
# 158                        7842                     13371
# 246                        6576                     11550
# 220                        6172                     11903
# 444                        3797                      6556
# 59                        31108                     52005
# 68                         9975                     14116
# 665                       66035                    115947
# 464                        3591                      6429
# 400                       17191                     31816
# 173                       21454                     35147
# 713                       12794                     24156
# 602                        9184                     15991
# 595                       17765                     30574
# 742                       23688                     42312
# 812                        7245                     11887
# 377                        2025                      3945
# 350                        8008                     11978
# 883                       15316                     28294
# 722                       10718                     19101
# 125                       10985                     21540
# 159                       23822                     43623
# 896                       65686                    117492
# 834                        6008                     10962
# 105                       47296                     96287
# 608                      208810                    410308
# 555                       16510                     28282
# 564                        4423                      9323
# 500                       10330                     20069
# 163                       96921                    177347
# 703                       11258                     21287
# 6                          4961                     10659
# 838                       29865                     53825
# 212                       61153                    117553
# 692                        4438                     10152
# 768                        3586                      6718
# 629                        7360                     13463
# 182                        1613                      3701
# 465                        4029                      8049
# 166                       17141                     33893
# 696                       16324                     32138
# 752                       22724                     42685
#
#      male_never_married_35_39  \
# 543                     13964
# 603                     17791
# 434                      1061
# 345                      7255
# 491                      7156
# 90                       9210
# 47                      65185
# 406                      6828
# 185                      7245
# 158                      9178
# 246                      7259
# 220                      7919
# 444                      4259
# 59                      31758
# 68                      10147
# 665                     71310
# 464                      3691
# 400                     18934
# 173                     23253
# 713                     15275
# 602                      9554
# 595                     20186
# 742                     29073
# 812                      8461
# 377                      2568
# 350                      7876
# 883                     16993
# 722                     11354
# 125                     12844
# 159                     26694
# 896                     72422
# 834                      6471
# 105                     50935
# 608                    245362
# 555                     18407
# 564                      6215
# 500                     13819
# 163                    114230
# 703                     13294
# 6                        6951
# 838                     35295
# 212                     68332
# 692                      6250
# 768                      4173
# 629                      9649
# 182                      2445
# 465                      4417
# 166                     22183
# 696                     19977
# 752                     29118
#
#     metropolitan statistical area/micropolitan statistical area       fdi  \
# 543                                              32820           0.027814
# 603                                              35380           0.026634
# 434                                              28180           0.227137
# 345                                              24660           0.035365
# 491                                              30780           0.017455
# 90                                               13820           0.014993
# 47                                               12060           0.059224
# 406                                              27140           0.020392
# 185                                              17900           0.020872
# 158                                              16700           0.011127
# 246                                              20500           0.041152
# 220                                              19430           0.013780
# 444                                              28660           0.023940
# 59                                               12580           0.044874
# 68                                               12940           0.017212
# 665                                              37980           0.046611
# 464                                              29540           0.016615
# 400                                              26900           0.027667
# 173                                              17460           0.018514
# 713                                              40060           0.033507
# 602                                              35300           0.036364
# 595                                              34980           0.019782
# 742                                              41180           0.017060
# 812                                              44140           0.015190
# 377                                              25900           0.143864
# 350                                              24860           0.009213
# 883                                              47260           0.029504
# 722                                              40380           0.018653
# 125                                              15380           0.024399
# 159                                              16740           0.033090
# 896                                              47900           0.078696
# 834                                              45060           0.017610
# 105                                              14460           0.062070
# 608                                              35620           0.096784
# 555                                              33340           0.029299
# 564                                              33700           0.061194
# 500                                              31140           0.014170
# 163                                              16980           0.052245
# 703                                              39580           0.041154
# 6                                                10420           0.019577
# 838                                              45300           0.027320
# 212                                              19100           0.064659
# 692                                              39100           0.016372
# 768                                              42340           0.022551
# 629                                              36540           0.021279
# 182                                              17780           0.038496
# 465                                              29620           0.023175
# 166                                              17140           0.017412
# 696                                              39300           0.022392
# 752                                              41700           0.037227
#
#        f_to_m  f_surplus
# 543  1.038869        874
# 603  1.003013         77
# 434  0.998388         -2
# 345  0.979362       -236
# 491  0.969559       -308
# 90   0.945201       -873
# 47   0.942076      -5712
# 406  0.930167       -644
# 185  0.928321       -920
# 158  0.927978       -963
# 246  0.921558       -906
# 220  0.914475      -1018
# 444  0.907566       -606
# 59   0.906490      -4863
# 68   0.898909      -1427
# 665  0.898074     -11818
# 464  0.895785       -670
# 400  0.882386      -3742
# 173  0.880986      -4183
# 713  0.877753      -2953
# 602  0.877243      -1963
# 595  0.876496      -3776
# 742  0.864696      -5725
# 812  0.858922      -1677
# 377  0.850951       -588
# 350  0.847721      -1824
# 883  0.846717      -4337
# 722  0.846395      -2934
# 125  0.843686      -3367
# 159  0.841712      -6905
# 896  0.840261     -18768
# 834  0.839901      -1755
# 105  0.838971     -15505
# 608  0.837673     -66604
# 555  0.834948      -4668
# 564  0.833959      -1548
# 500  0.828591      -3440
# 163  0.823031     -31385
# 703  0.818998      -3853
# 6    0.818745      -1932
# 838  0.817390      -9829
# 212  0.815649     -21671
# 692  0.812943      -1899
# 768  0.812891      -1257
# 629  0.809775      -2561
# 182  0.807620       -712
# 465  0.807305      -1551
# 166  0.800637      -6757
# 696  0.800143      -6423
# 752  0.797564      -8641
